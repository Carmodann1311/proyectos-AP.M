# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/proyectos-AP.M/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# VEMOS LOS TIPOS DE VARIBLES DEL DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Lucia to Maria
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sexo         10 non-null     object
#  1   Centro       10 non-null     object
#  2   Semestre     10 non-null     int64
#  3   Matematicas  10 non-null     float64
#  4   Ciencias     10 non-null     float64
#  5   Espanol      10 non-null     float64
#  6   Historia     10 non-null     float64
#  7   Deportes     10 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 720.0+ bytes

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON ILOC
# OBTENEMOS LAS PRIMERAS 5 FILAS
df.iloc[0: 5]
# Out:
#                  Sexo    Centro  Semestre  Matematicas  Ciencias  Espanol  \
# Estudiante
# Lucia        Femenino       MAC         5          7.0       6.5      9.2
# Pedro       Masculino       GAM         6          7.5       9.4      7.3
# Ines         Femenino  Coyoacán         7          7.6       9.2      8.0
# Luis        Masculino       MAC         7          5.0       6.5      6.5
# Andres      Masculino       GAM         5          6.0       6.0      7.8
#
#             Historia  Deportes
# Estudiante
# Lucia            8.6       8.0
# Pedro            7.0       7.0
# Ines             8.0       7.5
# Luis             7.0       9.0
# Andres           8.9       7.3

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON INDICE
# OBTENEMOS LOS ALUMNOS LUIS Y ANFRES
df.iloc[3: 5]
# Out:
#                  Sexo Centro  Semestre  Matematicas  Ciencias  Espanol  \
# Estudiante
# Luis        Masculino    MAC         7          5.0       6.5      6.5
# Andres      Masculino    GAM         5          6.0       6.0      7.8
#
#             Historia  Deportes
# Estudiante
# Luis             7.0       9.0
# Andres           8.9       7.3

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON ILOC
# # OBTENEMOS LOS ALUMNOS ANDRES Y CARLOS
df.iloc[ [4,6] , :]
# Out:
#                  Sexo Centro  Semestre  Matematicas  Ciencias  Espanol  \
# Estudiante
# Andres      Masculino    GAM         5          6.0       6.0      7.8
# Carlos      Masculino    GAM         6          6.3       6.4      8.2
#
#             Historia  Deportes
# Estudiante
# Andres           8.9       7.3
# Carlos           9.0       7.2

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON ILOC
# OBTENEMOS EL SEMESTRE DE TODOS LOS ALUMNOS
df.iloc[ :, 2:3]
# Out:
#             Semestre
# Estudiante
# Lucia              5
# Pedro              6
# Ines               7
# Luis               7
# Andres             5
# Ana                7
# Carlos             6
# Jose               7
# Sonia              5
# Maria              6

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON ILOC
# OBTENEMOS CENTRO Y MATEMATICAS DE TODOS LOS ALUMNOS
df.iloc[ :, [1,3]]
# Out:
#               Centro  Matematicas
# Estudiante
# Lucia            MAC          7.0
# Pedro            GAM          7.5
# Ines        Coyoacán          7.6
# Luis             MAC          5.0
# Andres           GAM          6.0
# Ana         Coyoacán          7.8
# Carlos           GAM          6.3
# Jose             MAC          7.9
# Sonia       Coyoacán          6.0
# Maria            MAC          6.8

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON ILOC
# # OBTENEMOS DE LOS ALUMNOS ANDRES Y CARLOS
# LAS CALIFICACIONES DE CIENCIAS E HISTORIA
df.iloc[ [4,6] , [4,6]]
# Out:
#             Ciencias  Historia
# Estudiante
# Andres           6.0       8.9
# Carlos           6.4       9.0

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# FILTRAR TODAS LAS FILAS Y COLUMNAS
df.loc[:]
# Out:
#                  Sexo    Centro  Semestre  Matematicas  Ciencias  Espanol  \
# Estudiante
# Lucia        Femenino       MAC         5          7.0       6.5      9.2
# Pedro       Masculino       GAM         6          7.5       9.4      7.3
# Ines         Femenino  Coyoacán         7          7.6       9.2      8.0
# Luis        Masculino       MAC         7          5.0       6.5      6.5
# Andres      Masculino       GAM         5          6.0       6.0      7.8
# Ana          Femenino  Coyoacán         7          7.8       9.6      7.7
# Carlos      Masculino       GAM         6          6.3       6.4      8.2
# Jose        Masculino       MAC         7          7.9       9.7      7.5
# Sonia        Femenino  Coyoacán         5          6.0       6.0      6.5
# Maria        Femenino       MAC         6          6.8       7.2      8.7
#
#             Historia  Deportes
# Estudiante
# Lucia            8.6       8.0
# Pedro            7.0       7.0
# Ines             8.0       7.5
# ...

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# FILTRAR TODAS LAS FILAS Y COLUMNAS
df.loc["Lucia"]
# Out:
# Sexo           Femenino
# Centro              MAC
# Semestre              5
# Matematicas         7.0
# Ciencias            6.5
# Espanol             9.2
# Historia            8.6
# Deportes            8.0
# Name: Lucia, dtype: object

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# OBTENER LA COLUMNA CENTRO
df.loc[:, "Centro"]
# Out:
# Estudiante
# Lucia          MAC
# Pedro          GAM
# Ines      Coyoacán
# Luis           MAC
# Andres         GAM
# Ana       Coyoacán
# Carlos         GAM
# Jose           MAC
# Sonia     Coyoacán
# Maria          MAC
# Name: Centro, dtype: object

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# OBTENER TODAS LAS COLUMNAS DEL ALUMNO CARLOS
df.loc[ "Carlos" ,:]
# Out:
# Sexo           Masculino
# Centro               GAM
# Semestre               6
# Matematicas          6.3
# Ciencias             6.4
# Espanol              8.2
# Historia             9.0
# Deportes             7.2
# Name: Carlos, dtype: object

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# OBTENER EL CENTRO AL QUE ASISTE INES
df.loc[ ["Ines"] ,["Centro"]]
# Out:
#               Centro
# Estudiante
# Ines        Coyoacán

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# OBTENER EL CENTRO Y SEMESTRE AL QUE ASISTE ANDRES
df.loc["Andres", ["Centro", "Semestre"] ]
# Out:
# Centro      GAM
# Semestre      5
# Name: Andres, dtype: object

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# OBTENER EL SEMESTRE DE LUCIA Y MARIA
df.loc[ ["Lucia", "Maria"], ["Semestre"] ]
# Out:
#             Semestre
# Estudiante
# Lucia              5
# Maria              6

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# OBTENER TODAS LAS CALIFICACIONES DE LUIS Y SONIA
df.loc[ ["Luis", "Sonia"], ["Matematicas", "Ciencias", "Español",
                            "Historia", "Deportes"] ]

# %%
import pandas as pd
#CARGAMOS EL ARCHIVO Y LE ASIGNAMOS EL INDICE
df = pd.read_excel("/Alumnos.xlsx", index_col=0)
# FILTRAMOS CON LOC
# CON UN RANGO DE COLUMNAS
df.loc[ ["Luis", "Sonia"], "Matematicas":"Deportes"]
# Out:
#             Matematicas  Ciencias  Espanol  Historia  Deportes
# Estudiante
# Luis                5.0       6.5      6.5       7.0       9.0
# Sonia               6.0       6.0      6.5       5.5       8.7
