# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/proyectos-AP.M/blob/main/Actividad1_2_Roberto_Daniel_Rodriguez_Carmona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ejercicio 1 f(x,y)=x+y+z=4

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x = 1
y = 2
z = -1


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x, y, z, color='r', s=100, label='(1, 2, -1)')


ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')


plt.title('Gráfica del punto (1, 2, -1)')


plt.legend()
plt.show()

# %% [markdown]
# ejercicio 2 f(x,y)=x+y+z=2

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_val, y_val, z_val = 1, 2, -3


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x_val, y_val, z_val, color='red', s=100, label='(1, 2, -3)')


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')


ax.set_title('Point (1, 2, -3) in 3D Space')


plt.show()

# %% [markdown]
# ejercicio 3 f(x,y)=x+y+z=0

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


x_val, y_val, z_val = 1, 2, -5


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x_val, y_val, z_val, color='red', s=100, label='(1, 2, -5)')


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')


ax.set_title('Point (1, 2, -5) in 3D Space')


plt.show()
